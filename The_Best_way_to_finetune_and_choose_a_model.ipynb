# %% [markdown]
# <a href="https://colab.research.google.com/github/Naitik1245/Machine_Learning/blob/main/The_Best_way_to_finetune_and_choose_a_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import svm,datasets
iris=datasets.load_iris()
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
df=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df['flower']=iris.target

# %%
df['flower']=df['flower'].apply(lambda x:iris.target_names[x])

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    flower
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # **Choosing the Best Model**

# %%
param_grid = [
    {
        'model': [svm.SVC(gamma='auto')],
        'model__C': [1, 10, 20],
        'model__kernel': ['rbf', 'linear']
    },
    {
        'model': [RandomForestClassifier()],
        'model__n_estimators': [1, 5, 10]
    },
    {
        'model': [LogisticRegression(solver='liblinear', multi_class='auto')],
        'model__C': [1, 5, 10]
    }
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline([
    ('model',None)
])

# %%
scoring_metric='accuracy'

# %%
grid=GridSearchCV(pipe,param_grid,cv=5,scoring=scoring_metric)
result=grid.fit(iris.data,iris.target)

# %%
print('Best parameters:', result.best_params_)
print('Best score:', result.best_score_)
# Out:
# Best parameters: {'model': SVC(gamma='auto'), 'model__C': 1, 'model__kernel': 'linear'}
# Best score: 0.9466666666666667

# %%
import pandas as pd
cv_results_df = pd.DataFrame(result.cv_results_)
cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001543      0.000212         0.001391        0.000140
# 1        0.001222      0.000045         0.001395        0.000267
# 2        0.001371      0.000094         0.001268        0.000034
# 3        0.001267      0.000144         0.001313        0.000179
# 4        0.001369      0.000086         0.001290        0.000046
# 5        0.001217      0.000026         0.001219        0.000016
# 6        0.002837      0.000181         0.001749        0.000050
# 7        0.008255      0.000211         0.002072        0.000110
# 8        0.017217      0.002196         0.002896        0.000752
# 9        0.001475      0.000125         0.001160        0.000041
# 10       0.002136      0.000193         0.001741        0.000383
# 11       0.002146      0.000192         0.001588        0.000073
#
#                                           param_model  param_model__C  \
# ...

# %%
result.best_params_
# Out:
# {'model': SVC(gamma='auto'), 'model__C': 1, 'model__kernel': 'linear'}
